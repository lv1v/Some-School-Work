# %%
marks = int(input("Enter the marks: "))

if marks > 90:
    grade = "A"
elif marks > 80:
    grade = "B"
elif marks > 70:
    grade = "C"
elif marks > 60:
    grade = "D"
else:
    grade = "E"

print("The grade is:", grade)
# Out:
# Enter the marks: 79
# The grade is: C
